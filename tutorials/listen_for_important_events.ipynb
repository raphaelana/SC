# %% [markdown]
# # Listen For Important Events
#
# - The goal of this tutorial is to introduce how to use the filtered stream and sample stream endpoints.
# - More details can be found - [FilteredStream](https://developer.twitter.com/en/docs/tutorials/listen-for-important-events)
# - This code is based on [SampleCodeFilteredStream](https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/main/Filtered-Stream/filtered_stream.py) repository.

# %% [markdown]
# ## Import Required Modules

# %%
import requests
import os
import json

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# - You would need to set up the bearer token, from your twitter App developer dashboard, for secure point of entry to use the twitter API.
# - The bearer token can be found on your twitter App developer dashboard under the "keys and tokens" page of the desired twitter app, for more details check out [BearerToken](https://developer.twitter.com/en/docs/authentication/oauth-2-0/bearer-tokens) <br>
# - A secure way to use your credentials is by creating environment variables in your terminal.
# ```console
# export 'BEARER_TOKEN'='xxxx'
# ```
# - bearer_oauth is used for bearer_token authorization.

# %%
bearer_token = os.environ.get("BEARER_TOKEN")

def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FilteredStreamPython"
    return r

# %% [markdown]
# ## Sample Stream
#
# - You can use the sample stream endpoint to get 1% of all tweets happening on twitter.
# - Based on these tweets you can pick up trends and popular topics among them.
# - You can access the sample stream endpoint using create_url.
# - To get response from the end point you can use connect_to_endpoint

# %%
def create_url():
    return "https://api.twitter.com/2/tweets/sample/stream"

# %%
def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth, stream=True)
    print(response.status_code)
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )

# %% [markdown]
# ## Test Run to Get 1% of All Activity on Twitter

# %%
url = create_url()
timeout = 0
while True:
    connect_to_endpoint(url)
    timeout += 1
# Out:
# 200
# {
#     "data": {
#         "id": "1509159350589345795",
#         "text": "@JacobusPasser Geht ja nur darum die eigenen Entscheidungen vor dem Ego zu rechtfertigen..."
#     }
# }
# {
#     "data": {
#         "id": "1509159350572654592",
#         "text": "@MacBudkowski @paulg Many people on twitter are na\u00efve, idealistic children (regardless of their age)"
#     }
# }
# {
#     "data": {
#         "id": "1509159350606053381",
#         "text": "bokuatsu\nhey, you got yourself a pretty little mouth, I think I wanna rub it the wrong way"
#     }
# }
# {
#     "data": {
#         "id": "1509159350576705540",
#         "text": "RT @_candyclover: #JungKook IG Q&amp;A:\n\n\ud83d\udc9c: \u0e41\u0e19\u0e30\u0e19\u0e33 Alice in Borderland \u0e08\u0e23\u0e34\u0e07 \u0e46 \u0e04\u0e48\u0e30!! \u0e2a\u0e19\u0e38\u0e01\u0e21\u0e32\u0e01 \ud83d\udc9c\ud83d\udc9c\n\u3134 #\u0e14\u0e39\u0e41\u0e19\u0e49\u0e27 \nhttps://t.co/pcJjkJbnxX\n\n\ud83d\udc9c: The Uncann\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350572662787",
#         "text": "@eldestape_radio Claudio Moroni, Ministro de @alferdez en di\u00e1logo con @robdnavarro #Navarro2023 IGNORA la realidad!\n\"Los n\u00fameros no me dicen eso\" responde ante la pregunta \"UD. cree que el gobierno no tiene que intervenir en un aumento de salarios?\"\n\ud83d\udce2 Salga del despacho sr. Ministro! Es AHORA!"
#     }
# }
# {
#     "data": {
#         "id": "1509159350581047296",
#         "text": "@kafa10milyon500 yok13"
#     }
# }
# {
#     "data": {
#         "id": "1509159350605996039",
#         "text": "RT @awatokushimaTV: \u3044\u3084\u30fc\u3082\u3046\u3059\u3050(4\u67081\u65e5\u304b\u3089)\u3067\u3059\u306d\uff01\n\u56fd\u5185\u521d\u306e\u9244\u9053\u3068\u30d0\u30b9\u306e\u5354\u529b\uff01\n\n\u5fb3\u5cf6\u30d0\u30b9\u306e0\u756a\u306e\u308a\u3070\u306b\u306f\u611f\u52d5\u3067\u3059(ToT)\n\n\u3053\u306e\u4ef6\u3068\u3044\u3044\u3001DMV\u3068\u3044\u3044\u3001\u5357\u90e8\u81ea\u52d5\u8eca\u9053\u3068\u3044\u3044\u3001\u6700\u8fd1\u306f\u770c\u5357\u304c\u30a2\u30c4\u3044\u3067\u3059\u306d\uff01\n\n\u3053\u308c\u304b\u3089\u306e\u660e\u308b\u3044\u672a\u6765\u306b\u671f\u5f85\uff01\uff01\n#\u6625\u4f11\u307f\u306f\u5fb3\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350593634308",
#         "text": "@kafa10milyon500 Var14"
#     }
# }
# {
#     "data": {
#         "id": "1509159329630687244",
#         "text": "RT @chevoire_: 1 winner ~ 180 mins \u02d7\u02cf\u02cb \u2661 \u02ce\u02ca\u02d7\n\n \u2014 Rt, Follow @Arki_Hwander"
#     }
# }
# {
#     "data": {
#         "id": "1509159329634693120",
#         "text": "RT @Neeko_Spanish: A ver cuanta gente quiere ponerme as\u00ed~ https://t.co/NHnz7sddw2"
#     }
# }
# {
#     "data": {
#         "id": "1509159350580834310",
#         "text": "@Mohijahon_NFT \ud83d\udea8Oceanpad \ud83c\udf0a#OPAD \n\n\u2705 Decentralized launchpad(BSC/ETH)\n\u2705 Liquidity locking services\n\u2705 Token creation services \n\u2705 Vetting &amp; KYC services \n\u2705 Smart contract audits \n\u2705 Token locking and vesting services \n\u2705 Data analytics services\nTG: https://t.co/xNmEof2FxW\n@Oceanpad_"
#     }
# }
# {
#     "data": {
#         "id": "1509159350568624128",
#         "text": "RT @_matsup_: \u5c3f\u4e2d\u306b\u542b\u307e\u308c\u308b\u3082\u306e\u3067\u80a5\u6599\u3068\u3057\u3066\u5f79\u7acb\u3064\u306e\u306f\u5c3f\u7d20\u3001\u30ea\u30f3\u9178\u3001\u30ab\u30ea\u30a6\u30e0\u3067\u3001\u5c3f\u306f\u571f\u58cc\u4e2d\u306b\u5165\u308a\u5c3f\u7d20\u306f\u571f\u58cc\u5fae\u751f\u7269\u306e\u50cd\u304d\u3067\u30a2\u30f3\u30e2\u30cb\u30a2\u3068\u4e8c\u9178\u5316\u70ad\u7d20\u306b\u5206\u89e3\u3055\u308c\u3001\u30a2\u30f3\u30e2\u30cb\u30a2\u306f\u305d\u306e\u307e\u307e\u304b\u7d30\u83cc\u306e\u4f5c\u7528\u3067\u785d\u9178\u3068\u306a\u3063\u3066\u690d\u7269\u306b\u5438\u53ce\u3055\u308c\u308b\u306e\u3067\u80a5\u6599\u3068\u3057\u3066\u6709\u52b9\u3067\u3042\u308b"
#     }
# }
# {
#     "data": {
#         "id": "1509159350593818625",
#         "text": "RT @Airdrop365Team: Airdrop: #CCI\n\ud83c\udf81 Prize Pool: Over $666,666 USDT \n\ud83d\udc8e Winners\uff1aAll Users\n\ud83c\udfc6 NFT Winners: 666+ Randomly\n\ud83d\udc40Per participant: 3 $C\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350585081856",
#         "text": "RT @auji_sonal: Teju is Really Safe with jiju. \nThank you for your sweet Gesture @kkundrra jiju \u2764\n\n#TejasswiPrakash #TejaTroops #TejRan"
#     }
# }
# {
#     "data": {
#         "id": "1509159350568251400",
#         "text": "RT @mycutedoppio: \ub514\uc5d0\ud32c\uce20\nhttps://t.co/6jx3PXL6Ul\n\n\ub458\uc774 \ud0a4\uc2a4\ub97c \ud569\ub2c8\ub2e4.. \uadf8\uac8c \ub2e4\uc785\ub2c8\ub2e4......\n\uce90\ubd95 \uc788\uc74c \uc5b8\uc81c \ub0b4\ub824\uac08\uc9c0 \ubaa8\ub984"
#     }
# }
# {
#     "data": {
#         "id": "1509159350593486855",
#         "text": "RT @archiveforJK: jeon jungkook oh my god. https://t.co/FdYgpI4A7x"
#     }
# }
# {
#     "data": {
#         "id": "1509159350589292545",
#         "text": "@Riisa_0904 \u304a\u3051\u304a\u3051w"
#     }
# }
# {
#     "data": {
#         "id": "1509159350589267971",
#         "text": "RT @kimcchhii: https://t.co/QX3yTJg3aA"
#     }
# }
# {
#     "data": {
#         "id": "1509159350568423427",
#         "text": "RT @Moreno_fdez: Es desmoralizante ver la decrepitud en la que ha entrado la sociedad espa\u00f1ola y el futuro tan triste y pobre que le espera\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350602022915",
#         "text": "@kafa10milyon500 Yokoet"
#     }
# }
# {
#     "data": {
#         "id": "1509159350597738500",
#         "text": "RT @Perseved: #NoToHealthActAmendment\nWhat happened to our human rights. What is the point of having people we voted for in power while the\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159329613504517",
#         "text": "RT @itsteddybear_: \u2728\u09ac\u09be\u0997\u09be\u09a8\u09bf https://t.co/lsSW4VPgI0"
#     }
# }
# {
#     "data": {
#         "id": "1509159350585200652",
#         "text": "@MrGee54 Facts!"
#     }
# }
# {
#     "data": {
#         "id": "1509159350577037317",
#         "text": "@dream_setomari \u7121\u610f\u8b58\u3067\u3057\u305f\u304b\ud83d\ude02 \u898b\u305f\u77ac\u9593\u306b\u30bb\u30c8\u30de\u30ea\u3055\u3093\u30ab\u30e9\u30fc\u5c3d\u304f\u3057\u3058\u3083\u3093\u3068\u30ef\u30af\u30ef\u30af\u3068\u30ea\u30d7\u9001\u308a\u307e\u3057\u305f(  \u00b4\ua4b3` )\u0a6d\"\ud83d\udc95\ud83d\udc95\ud83c\udf38\u7b11\n\u30de\u30ea\u30ca\u3055\u3093\u306e\u670d\u3082\u6625\u3089\u3057\u304f\u3066\u7d20\u6575\u3067\u3059\u2661\n\u3042\u3063\u548c\u670d\u3082\u826f\u3044\u3067\u3059\u306d\u2026\u591c\u685c\u304c\u4f3c\u5408\u3044\u305d\u3046\u3067\u3068\u3066\u3082\u597d\u304d\u3067\u3059\u2026\ud83d\ude4f\u2764\u7f8e\u5473\u3057\u3044\u30cd\u30bf\u5b09\u3057\u3044\u3067\u3059\u2026\ud83e\udd24\u2661"
#     }
# }
# {
#     "data": {
#         "id": "1509159350585200641",
#         "text": "cute, someone do this to me please https://t.co/psz5ZCcw2j"
#     }
# }
# {
#     "data": {
#         "id": "1509159333804011520",
#         "text": "[\ud55c\uad6d\uc778 \uc774\ub9cc\ud76c \ud3c9\ud654\uc2e4\ud654\u2502\uc804\uc7c1\uc885\uc2dd \uad6d\uc81c\ubc95&lt;5&gt;] \ub3d9\uc720\ub7fd\u2027\ubc94\uc544\ud504\ub9ac\uce74\u2027\ud0dc\ud3c9\uc591\u2027\uce74\ub9ac\ube0c\uc81c\ub3c4 \uae00\ub85c\ubc8c \ub9ac\ub354\ub4e4 DPCW \uc9c0\uc9c0 https://t.co/loeKaqmEdN"
#     }
# }
# {
#     "data": {
#         "id": "1509159350576812032",
#         "text": "RT @Sweet_Trade_dug: @qaomene You have to stand by helplessly while a loved one deals with a disease that fucks with their sense of self an\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159333799424005",
#         "text": "@kw0nn_fire @ChoeaedolSUMIN https://t.co/hncPrZLnR4"
#     }
# }
# {
#     "data": {
#         "id": "1509159350597693443",
#         "text": "RT @Monika_Yadav__: #HiddenSecrets_Of_TheQuran\nWhom the Muslim brothers believe in God, whom he tells above himself, the real God? https://\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350568316935",
#         "text": "RT @googiefolder: jungkook instagram story update\n\n\ud83d\udc30 netflix recommendations let's go \n\n\ud83d\udc64 the end of the f...ing world \n\ud83d\udc30 #/the end of the\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350585421828",
#         "text": "@Remi____04 \u3081\u3063\u3061\u3083\u4ef2\u826f\u304f\u306a\u308b\u3057\uff01(\u7b11)"
#     }
# }
# {
#     "data": {
#         "id": "1509159350593499137",
#         "text": "@iam_ms_official \ud83d\udc4c"
#     }
# }
# {
#     "data": {
#         "id": "1509159350597677056",
#         "text": "RT @onlyfordonbelle: Lol it\u2019s the censored part and the \u201cI like her, we\u2019re friends\u201d for me \ud83d\ude0c halatang may something hshshs tumiklop bigla s\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350606053376",
#         "text": "RT @itsbtszone: i think it's high time we all agree that bts are indeed carrying the music industry on their backs. https://t.co/0m15fNfqkZ"
#     }
# }
# {
#     "data": {
#         "id": "1509159350606118916",
#         "text": "@mcollina86 @dax989 Podobny styl, tylko wyniki inne, dlatego to Michniewicz robi karier\u0119;)"
#     }
# }
# {
#     "data": {
#         "id": "1509159350568644613",
#         "text": "Ye la dulu akak aku belikan laptop wehh \ud83d\ude2d\ud83d\ude2d\ud83d\ude2d"
#     }
# }
# {
#     "data": {
#         "id": "1509159350589624321",
#         "text": "RT @malgum_0710: \uace0\uc6b0\ub9bc \uc2b9\ucc9c\ud560\uae4c\ubd10 \n\ub0a0\uac1c\ub294 \uc81c\uac00 \ud6d4\ucce4\uc2b5\ub2c8\ub2e4( https://t.co/l7OPzldqKX"
#     }
# }
# {
#     "data": {
#         "id": "1509159350602203137",
#         "text": "\u30df\u30b9\u30bf\u2026 \u3042\u306a\u305f\u306e\u300c\u899a\u609f\u300d\u306f\u2026\u3053\u306e\u767b\u308a\u3086\u304f\u671d\u65e5\u3088\u308a\u3082\u660e\u308b\u3044\u8f1d\u304d\u3067\u300e\u9053\u300f\u3092\u7167\u3089\u3057\u3066\u3044\u308b \u305d\u3057\u3066\u6211\u3005\u304c\u3053\u308c\u304b\u3089\u300e\u5411\u304b\u3046\u3079\u304d\u2026\u6b63\u3057\u3044\u9053\u300f\u3092\u3082\u30c3\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1509159350576640005",
#         "text": "RT @nhk_news: \u9577\u91ce\u770c\u4f50\u4e45\u5e02\u306e\u7267\u5834\u3067\u30e4\u30ae\u306e\u51fa\u7523\u304c\u30d4\u30fc\u30af\u3092\u8fce\u3048\u3001\u304b\u308f\u3044\u3089\u3057\u3044\u30e4\u30ae\u306e\u8d64\u3061\u3083\u3093\u304c\u6b21\u3005\u3068\u751f\u307e\u308c\u3066\u3044\u307e\u3059\u3002\nhttps://t.co/Hq83RM3ynt\n#nhk_video https://t.co/43KaC6nnQL"
#     }
# }
# {
#     "data": {
#         "id": "1509159350576713733",
#         "text": "@kingqueen00854 \u30a2\u30d4\u30fc\u30eb\u305b\u3093\u3067\u3082\u3082\u3046\u5fd8\u308c\u3078\u3093\ud83e\udd23\ud83e\udd23\ud83e\udd23\n\u8a71\u3057\u304b\u3051\u306b\u6765\u3066\u306a\ud83e\udd7a"
#     }
# }
# {
#     "data": {
#         "id": "1509159350593458176",
#         "text": "\u304a\u306f\u3088\u3046\u3054\u3056\u3044\u307e\u3059(\u6b7b)"
#     }
# }
# {
#     "data": {
#         "id": "1509159350568644614",
#         "text": "RT @himajingoroshi: \u5f15\u304d\u3084\u3070\u3059\u304e\u308bw https://t.co/EEhVDHsDkA"
#     }
# }
# {
#     "data": {
#         "id": "1509159350593540099",
#         "text": "fdp rezando para que todas mis calificaciones salgan bien y no terminen cagando mi cum"
#     }
# }
# {
#     "data": {
#         "id": "1509159350576848898",
#         "text": "Nashville- A crash on I-40 west bound @ Briley Pkwy near the Airport 8:24am CT.\nWatch \"LIVE\" traffic video now @ https://t.co/jRIPo43joK #Traffic #TennesseeTraffic #wreck #crash #accident #interstate #Nashville https://t.co/TlYH3sZPG8"
#     }
# }
# {
#     "data": {
#         "id": "1509159350589599745",
#         "text": "I am in the running to win the Trustizen Massive  Airdrop with the Prizepool of $100,000  USD \ud83d\udc40\ud83d\ude31 ,Check it out to participate #BigGiveaway #Airdrop #BNB $TTZ #WebcoinCapital https://t.co/X7FBhuWBwt"
#     }
# }
# {
#     "data": {
#         "id": "1509159350602203141",
#         "text": "\u3082\u3046\u3055 KinKi\u3061\u3083\u3093\u306e\u6620\u50cf\u7d42\u308f\u308a\u304b\u306a\u3002\u3002\u30025\u30c8\u30f3\u89b3\u3066\u304d\u3066\u3044\u3044\u304b\u306a"
#     }
# }
# {
#     "data": {
#         "id": "1509159350589595649",
#         "text": "\u3084\u3079\u3047\u3001\u7d75\u5168\u7136\u63cf\u3044\u3066\u306a\u3044"
#     }
# }
# {
#     "data": {
#         "id": "1509159350576820225",
#         "text": "RT @AbasAslani: #Iran FM @Amirabdolahian met #Pakistan FM @SMQureshiPTI on the sideline of the third meeting of foreign ministers of neighb\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350597656576",
#         "text": "\u30b8\u30e7\u30f3\u30cf\u30f3\u3055\u3093\uff01\n\u30d3\u30b8\u30e5\u3001\u6b4c\u58f0\u3001\u30c0\u30f3\u30b9\u3082\u3082\u3061\u308d\u3093\u305d\u3046\u3060\u3051\u3069\n\u30e1\u30f3\u30d0\u30fc\u304c\u597d\u304d\u3059\u304e\u3066\u3044\u305f\u305a\u3089\u3057\u3061\u3083\u3046\u3068\u3053\u3068\u304b\u3072\u3068\u308a\u307c\u3063\u3061\u306b\u3055\u308c\u305f\u3089\u62d7\u306d\u3061\u3083\u3046\u3068\u3053\u3068\u304b\n\u3082\u3046\u5168\u3066\uff01\n\u3067\u3082\u7d50\u5c40\u3069\u306e\u30e1\u30f3\u30d0\u30fc\u3082\u51c4\u3044\u9b45\u529b\u305f\u3063\u3077\u308a\u3060\u3057\u3001\u898b\u308c\u3070\u898b\u308b\u307b\u3069\u6cbc\u306b\u30cf\u30de\u3063\u3066\u304f\ud83e\udd70 https://t.co/0EajZgf9HF"
#     }
# }
# {
#     "data": {
#         "id": "1509159350597734402",
#         "text": "RT @BTSChartsDailyx: .@TIME has named @BTS_twt the Princes of Global Pop ! https://t.co/wci51NvKbg"
#     }
# }
# {
#     "data": {
#         "id": "1509159346407624710",
#         "text": "2 Days to go!\n\nThe excitement is building as our #SchoolsCompetition finalists prepare to travel to Croke Park for our exciting awards ceremony! \n\nWe are looking at the Runner up award today! \ud83c\udfc6 https://t.co/QFGqdK5Wv9"
#     }
# }
# {
#     "data": {
#         "id": "1509159350580916226",
#         "text": "\u30b9\u30c1\u30fc\u30e0\u30df\u30eb\u30af\u8150\u308b\u307b\u3069\u6301\u3063\u3066\u3066\u3081\u3063\u3061\u3083\u30ef\u30ed\u30bf"
#     }
# }
# {
#     "data": {
#         "id": "1509159350581227521",
#         "text": "\u2193\u8a18\u4e8b\u306e\u7d9a\u304d\u306f\u3053\u3061\u3089\u2193\nhttps://t.co/rFGczKjwuq"
#     }
# }
# {
#     "data": {
#         "id": "1509159350593417216",
#         "text": "@muku_owl 500\u5186\u4ee5\u4e0b\u3067\u3057\u3087\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1509159350601928710",
#         "text": "RT @EmbassyofRussia: FM #Lavrov: Isolation doesn\u2019t exist &amp; is brought up exclusively by those who mentally &amp; ideologically have resigned th\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159350602186755",
#         "text": "apa pulak rakyat berhutang aku rumah papan yang bagi bantuan pun masjid tiba tiba hutang yang atas beli semua cash hutang sikit je. https://t.co/49buGNWTiE"
#     }
# }
# {
#     "data": {
#         "id": "1509159350585102340",
#         "text": "RT @bebsays: \u0e0b\u0e49\u0e2d\u0e21\u0e21\u0e32\u0e2b\u0e21\u0e37\u0e48\u0e19\u0e23\u0e2d\u0e1a\u0e08\u0e32\u0e01\u0e17\u0e35\u0e48\u0e1a\u0e49\u0e32\u0e19\u0e02\u0e2d\u0e42\u0e0a\u0e27\u0e4c\u0e2b\u0e19\u0e48\u0e2d\u0e22 *\u0e41\u0e15\u0e30\u0e44\u0e2b\u0e25\u0e48* https://t.co/DCDGWDkRGX"
#     }
# }
# {
#     "data": {
#         "id": "1509159350585200646",
#         "text": "@Miss_Parker03 https://t.co/brndsHciWW"
#     }
# }
# {
#     "data": {
#         "id": "1509159350589440000",
#         "text": "@cmfuentez Van mij mag dat.  Dat betekent nu niet dat ik tegen de huidige sancties zou zijn omdat ze elders niet genomen werden.  Dat spel laat ik over aan anderen"
#     }
# }
# {
#     "data": {
#         "id": "1509159350576709632",
#         "text": "RT @Hoshikumo_oO: \u914d\u4fe1\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\ud83d\udc76\ud83c\udffb\ud83c\udfa4\ud83c\udfb6\n\n\u6b4c\u67a0\u307e\u305f\u3059\u308b(   \uff70\u0300\u058a\uff70\u0301 )\u0a6d\u270a\ud83c\udffb"
#     }
# }
# {
#     "data": {
#         "id": "1509159350576762881",
#         "text": "...#\u0627\u0644\u0645\u0627\u062a\u0634_\u064a\u062a\u0639\u0627\u0648\u062f"
#     }
# }
# {
#     "data": {
#         "id": "1509159350589394946",
#         "text": "@iam_azeezadio \ud83d\ude02"
#     }
# }
# {
#     "data": {
#         "id": "1509159350581227523",
#         "text": "RT @BBMeMeaw: \u0e01\u0e23\u0e35\u0e4a\u0e14\u0e14\u0e14 \u0e1e\u0e35\u0e48\u0e01\u0e31\u0e19\u0e15\u0e4c\u0e04\u0e19\u0e2e\u0e2d\u0e17  \ud83d\ude0d\ud83d\udc9a\nBamBam Fly To America\n#BamBamToUSA2022 #BamBam @BamBam1A @GOT7Official https://t.co/vSukYJZgb6"
#     }
# }
# {
#     "data": {
#         "id": "1509159350580879368",
#         "text": "@mhddn_ kd mempan"
#     }
# }
# {
#     "data": {
#         "id": "1509159350601875458",
#         "text": "RT @okoge_yade: #\u30a8\u30ec\u30ea\u306e\u30a8\u30ec\u30f3\u751f\u8a95\u796d2022\n\n\u300c\u3044\u3063\u3071\u3044\u795d\u3063\u3066\u3082\u3089\u3048\u3066\u826f\u304b\u3063\u305f\u306a\u300d\n\n\u304a\u3081\u3067\u3068\u3046\uff01\uff01\uff01\uff01\u3048\u308c\u3093\u304f\u3093\uff01\uff01\uff01\uff01 https://t.co/3xUSQXQ2z2"
#     }
# }
# {
#     "data": {
#         "id": "1509159354779512846",
#         "text": "RT @xhashtag_earn: \ud83e\ude82#xHashtag x @CropBytes #Airdrop Campaign is now extended! \ud83e\udd73\n\n\ud83d\udcb0Reward Pool: $10,000 worth #CBX\ud83e\udd11\n\n1\ufe0f\u20e3Do simple tasks\n2\ufe0f\u20e3G\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354796482561",
#         "text": "@ichigoskinano @cmsn_RT \uc624\ubbf8\uce74\uc138 \uac00\ub2a5! \ube60\ub9c8 \uac00\ub2a5! \uba54\uc778\ud2b8 \ub9c1\ud06c \ub458\ub7ec\ubd10\uc8fc\uc2dc\uace0 \ubb38\uc758\uc8fc\uc138\uc694\u263a\ufe0f\u2764\ufe0f"
#     }
# }
# {
#     "data": {
#         "id": "1509159354762956800",
#         "text": "@cutesillyy haloo"
#     }
# }
# {
#     "data": {
#         "id": "1509159354779377668",
#         "text": "RT @ABSCBNpr: Here are the TOP 10 MOVIES everyone's watching on iWantTFC!\nStream them all today! https://t.co/JYxNc2xMFV https://t.co/UHGRW\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354766872576",
#         "text": "@dontdelay @Calendly Isn't there a comma missing there? ;-)"
#     }
# }
# {
#     "data": {
#         "id": "1509159354800422919",
#         "text": "@chiamakaOH Thank you"
#     }
# }
# {
#     "data": {
#         "id": "1509159354775535618",
#         "text": "\u0e40\u0e23\u0e32\u0e40\u0e02\u0e49\u0e32\u0e43\u0e08\u0e27\u0e48\u0e32\u0e17\u0e38\u0e01\u0e04\u0e19\u0e21\u0e35\u0e04\u0e27\u0e32\u0e21\u0e04\u0e32\u0e14\u0e2b\u0e27\u0e31\u0e07\u0e19\u0e30\u0e04\u0e30 \u0e2d\u0e22\u0e32\u0e01\u0e43\u0e2b\u0e49\u0e04\u0e39\u0e48\u0e17\u0e35\u0e48\u0e40\u0e23\u0e32\u0e0a\u0e34\u0e1b\u0e1b\u0e31\u0e07\u0e46 \u0e41\u0e15\u0e48\u0e40\u0e23\u0e32\u0e27\u0e48\u0e32\u0e08\u0e30\u0e40\u0e23\u0e37\u0e2d\u0e25\u0e33\u0e44\u0e2b\u0e19 \u0e01\u0e47\u0e2d\u0e22\u0e48\u0e32\u0e17\u0e33\u0e43\u0e2b\u0e49\u0e28\u0e34\u0e25\u0e1b\u0e34\u0e19\u0e17\u0e35\u0e48\u0e40\u0e23\u0e32\u0e23\u0e31\u0e01\u0e15\u0e49\u0e2d\u0e07\u0e2b\u0e19\u0e31\u0e01\u0e43\u0e08\u0e40\u0e25\u0e22\u0e04\u0e48\u0e30 \u0e01\u0e32\u0e23\u0e22\u0e37\u0e19\u0e43\u0e19\u0e41\u0e2a\u0e07\u0e2a\u0e27\u0e48\u0e32\u0e07\u0e21\u0e31\u0e19\u0e40\u0e2b\u0e19\u0e37\u0e48\u0e2d\u0e22\u0e01\u0e27\u0e48\u0e32\u0e17\u0e35\u0e48\u0e1a\u0e32\u0e07\u0e04\u0e19\u0e40\u0e02\u0e49\u0e32\u0e43\u0e08\u0e08\u0e23\u0e34\u0e07\u0e46 \u0e16\u0e49\u0e32\u0e23\u0e31\u0e01\u0e19\u0e49\u0e2d\u0e07 \u0e40\u0e02\u0e49\u0e32\u0e43\u0e08\u0e19\u0e49\u0e2d\u0e07\u0e41\u0e25\u0e30\u0e0b\u0e31\u0e1e\u0e1e\u0e2d\u0e23\u0e4c\u0e15\u0e44\u0e21\u0e48\u0e27\u0e48\u0e32\u0e40\u0e23\u0e37\u0e2d\u0e44\u0e2b\u0e19\u0e19\u0e30\u0e04\u0e30\ud83e\udd0d\n\n#\u0e1e\u0e23\u0e49\u0e2d\u0e21\u0e21\u0e32\u0e23\u0e4c\u0e04 #\u0e1e\u0e23\u0e49\u0e2d\u0e21\u0e40\u0e1a\u0e19\u0e0b\u0e4c #\u0e1e\u0e23\u0e49\u0e2d\u0e21\u0e1c\u0e39\u0e49\u0e2d\u0e22\u0e39\u0e48\u0e01\u0e31\u0e1a\u0e43\u0e04\u0e23\u0e01\u0e47\u0e40\u0e1b\u0e47\u0e19\u0e41\u0e1f\u0e19"
#     }
# }
# {
#     "data": {
#         "id": "1509159354796167168",
#         "text": "@prosperiacnft @ernest_tew1 @KurooPepe @Tempesttrooper"
#     }
# }
# {
#     "data": {
#         "id": "1509159354787901449",
#         "text": "@Rubi_writes_ Ok"
#     }
# }
# {
#     "data": {
#         "id": "1509159354779705344",
#         "text": "RT @KapilMishra_IND: \u0938\u093f\u0938\u094b\u0926\u093f\u092f\u093e \u0915\u094b \u092c\u0921\u093c\u093e \u092e\u091c\u093e \u0906\u0924\u093e \u0939\u0948 \u0915\u0947\u091c\u0930\u0940\u0935\u093e\u0932 \u0915\u0940 \u0939\u0924\u094d\u092f\u093e \u0915\u0940 \u092c\u093e\u0924 \u0915\u0930\u0915\u0947\n\n\u091c\u092c \u092e\u0928 \u092e\u0947\u0902 \u0906\u0924\u093e \u0939\u0948 \u0915\u0947\u091c\u0930\u0940\u0935\u093e\u0932 \u0915\u0940 \u0939\u0924\u094d\u092f\u093e \u0915\u0940 \u092c\u093e\u0924 \u0915\u0930\u0928\u0947 \u0932\u0917\u0924\u093e \u0939\u0948\u0902\n\n\u092f\u0947\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354762629120",
#         "text": "@sharPexc928 \u7121\u9650\u306bmap\u3092\u56de\u308c"
#     }
# }
# {
#     "data": {
#         "id": "1509159354783911936",
#         "text": "@oo77269324 \u4eca\u7d76\u671b\u306e\u6df5\u306b\u7acb\u3063\u3066\n\u8e0f\u5207\u3078\u3068\u98db\u3073\u51fa\u3057\u305f"
#     }
# }
# {
#     "data": {
#         "id": "1509159354796474368",
#         "text": "@Turugi_syuuu \u5206\u89e3\u3057\u3066\u3064\u304f\u308b\u611f\u3058\u3067\u3059\u306d\uff01\uff1f\u306a\u3093\u3068\u306a\u304f\u308f\u304b\u308a\u307e\u3057\u305f\u3001\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1509159354762956804",
#         "text": "@YoichiTakahashi @zakdesk \u5148\u751f\u3082\u6a4b\u4e0b\u306b\u7d61\u307e\u308c\u3066\u308b\u3088\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1509159354783703052",
#         "text": "@boredkideth @Penior45 @reverolff @xLuisDavid1993x @Spidicsama"
#     }
# }
# {
#     "data": {
#         "id": "1509159354762727425",
#         "text": "RT @blognaointendo: Tomei essas p\u00edlulas e agora estou em outro n\u00edvel https://t.co/c0OvLsOjPJ"
#     }
# }
# {
#     "data": {
#         "id": "1509159354775212039",
#         "text": "RT @flowfess: ff followan yuk?? Rt jfb ya - jichu"
#     }
# }
# {
#     "data": {
#         "id": "1509159354783608834",
#         "text": "RT @GupTelly: Hot and Exclusive \ud83d\udd25\n#TeJran is the most*Loved couple non - fiction of the past 3 months\nMushkil \u0938\u0947 \u092e\u093f\u0932\u0924\u0947 \u0939\u0948 \u0910\u0938\u0947 selfless pyar\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354787897351",
#         "text": "RT @patriciapolitz: Senadora @ximerincon \u00bfpodr\u00eda explicar la comparaci\u00f3n de Pinochet con una @convencioncl elegida democr\u00e1ticamente por la\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354767114244",
#         "text": "RT @staff_SOLIDEMO: \uff0f\n\u4e2d\u5c71\u512a\u8cb4 Birthday Live\n\u4e00\u822c\u30c1\u30b1\u30c3\u30c8\u8ca9\u58f2\u6c7a\u5b9a\uff01\uff01\ud83c\udf82\u2728\n\uff3c\n\n2022\u5e744\u67086\u65e5(\u6c34)\n\u4f1a\u5834/\u6e0b\u8c37SPACE ODD\nOPEN/18:00\nSTART/18:30\nTICKET/\u00a55,500\uff08\u30c9\u30ea\u30f3\u30af\u4ee3\u5225\u9014\uff09\n\u203bSOLID\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159333820571648",
#         "text": "@smaneko56560 \n\u3054\u5fdc\u52df\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\n4/6\u307e\u3067\u4f7f\u3048\u308b\u300c\u30a6\u30c1\u30ab\u30d5\u30a7\u30b9\u30a4\u30fc\u30c4\u5404\u7a2e20\u5186\u5f15\u5238\u300d\u3092\u5dee\u3057\u4e0a\u3052\u307e\u3059\u3002\u307b\u3063\u3068\u3072\u3068\u606f\u306f\u30a6\u30c1\u30ab\u30d5\u30a7\u30b9\u30a4\u30fc\u30c4\u3067\u266a\u6b21\u56de\u3082\u30c1\u30e3\u30ec\u30f3\u30b8\u3057\u3066\u4e0b\u3055\u3044(^^)\n\u30af\u30fc\u30dd\u30f3\u306e\u4f7f\u3044\u65b9:https://t.co/PkAjcbYwLl #\u30ed\u30fc\u30bd\u30f3 https://t.co/sBG7ACoDZX"
#     }
# }
# {
#     "data": {
#         "id": "1509159354783698950",
#         "text": "RT @Raan1356: \u0628\u0639\u062f \u0644\u0641\u064a \u0628\u0627\u0644\u0647\u0634\u062a\u0627\u0642 \u0641\u0631\u062d\u062a \u0644\u0627\u0646\u064a \u0644\u0642\u064a\u062a\u0669\u0669 \u0660/\u0660 \u0645\u0646\u0647\u0645 \u0648\u0627\u0639\u064a\u0646 \u0648\u0645\u062f\u0631\u0643\u064a\u0646 \u062d\u0631\u0643\u0627\u062a \u0627\u0644f\u0633\u0648\u064a\u0627\u062a \u0648\u062e\u0637\u0637\u0647\u0645 \u0627\u0644\u0645\u062f\u0639\u0648\u0633\u0647 \u0648\u0645\u062d\u0630\u0631\u064a\u0646 \u0645\u0646\u0647\u0645 \u0648\u0645\u0646 \u0647\u0634\u062a\u0627\u0642\u0627\u062a\u0647\u0645 \u0648\u0645\u0646 \u0627\u0644\u0627\u0646\u0635\u064a\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354767147009",
#         "text": "RT @LetsOTT: is he driving a fighter jet?"
#     }
# }
# {
#     "data": {
#         "id": "1509159354783580166",
#         "text": "RT @Trey_Sebek_Omi: \u306f\u3044 https://t.co/mIKFU8ZW6x"
#     }
# }
# {
#     "data": {
#         "id": "1509159354792288259",
#         "text": "RT @orapanSTphoto: @LampaiThongdee @Petchriot @petchriotoff 55555\u0e1e\u0e35\u0e48\u0e15\u0e01\u0e40\u0e23\u0e37\u0e2d\u0e41\u0e25\u0e49\u0e27\u0e27\u0e27 \u0e25\u0e38\u0e07\u0e2d\u0e27\u0e14\u0e41\u0e1f\u0e19\u0e40\u0e01\u0e48\u0e07\u0e21\u0e32\u0e01\u0e04\u0e48\u0e30"
#     }
# }
# {
#     "data": {
#         "id": "1509159354792136712",
#         "text": "@JustinBennettFX Well done Justin &amp; thank you \ud83d\ude4f\ud83c\udffb"
#     }
# }
# {
#     "data": {
#         "id": "1509159354792132611",
#         "text": "@Loresvelo Tu \u00e9 dd, que foda"
#     }
# }
# {
#     "data": {
#         "id": "1509159354796105733",
#         "text": "@MjdwLOsQoazqQQo \u81ea\u5206\u3082\u30b5\u30c3\u30ab\u30fc\u5927\u597d\u304d\u306a\u3093\u3067\u30ef\u30fc\u30eb\u30c9\u30ab\u30c3\u30d7\u3086\u3063\u304f\u308a\u898b\u308c\u306a\u3044\u306e\u304c\u8f9b\u3044\u3067\u3059w"
#     }
# }
# {
#     "data": {
#         "id": "1509159354800476164",
#         "text": "RT @Metaverse_war: \ud83c\udfc6Buy at the lowest price and get the full profit / win the festival\n\n\ud83d\udd3650 random winners will receive $20 MVW\n\n\u2705Condition\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354800676872",
#         "text": "RT @inaeternumxxx: \u7d9a\u3044\u305f\n\u5927\u3057\u305f\u3053\u3068\u306a\u3044\u3051\u3069\u306c\u308b\u30a8\u30ed\u306a\u306e\u3067\u30dd\u30a4\u30d4\u30af\u306b\u6295\u4e0b\u3057\u307e\u3057\u305f\nhttps://t.co/YmaX0oRR4s https://t.co/EXv9r2YDAj"
#     }
# }
# {
#     "data": {
#         "id": "1509159354762600454",
#         "text": "RT @puspenpol: [Serial Tipe Partai Politik]\n\nPartai Sayap Kiri &amp; Kanan https://t.co/rnqKzQfVOt"
#     }
# }
# {
#     "data": {
#         "id": "1509159354779512840",
#         "text": "RT @lialimon: Hablando de disculpas p\u00fablicas, a los que est\u00e1n tan calificadores de la disculpa de @SandraCuevas_ les pregunto: y la disculp\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354800386054",
#         "text": "RT @WebKhabristan: Shehnaaz Gill Talks About SidNaaz, Says 'It Was Not Just a Hashtag, But My Everything'.\n\n#SidNaaz #ShehnaazGill https://\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354779709444",
#         "text": "RT @Peorudayo: \u91ce\u826f\u304c\u6f14\u6280\u6d3e\u3059\u304e\u308b\n\n#VALORANT https://t.co/AwdlRUCfk4"
#     }
# }
# {
#     "data": {
#         "id": "1509159354788085760",
#         "text": "@j3llymilk \u0e40\u0e21\u0e04\u0e40\u0e1f\u0e23\u0e19\u0e01\u0e31\u0e19\u0e19\u0e30\u0e2e\u0e30  &gt;&lt;"
#     }
# }
# {
#     "data": {
#         "id": "1509159354787774473",
#         "text": "\u3044\u307e\u982d\u307c\u3093\u3084\u308a\u3057\u3066\u3057\u305f\u3044\u3053\u3068\u304c\u3067\u304d\u306a\u3044\u306e\u3060"
#     }
# }
# {
#     "data": {
#         "id": "1509159354783703053",
#         "text": "RT @soniasodha: Hundreds of babies died or were left with life-altering injuries as a result of dreadful maternity care at this NHS Trust.\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354762600452",
#         "text": "RT @omochinasunoo: \u3053\u308c\u306a\u306b\uff1f\u65b0\u3057\u3044\u67089\uff1f https://t.co/1aXjnPL4Ys"
#     }
# }
# {
#     "data": {
#         "id": "1509159354762948611",
#         "text": "RT @saranjnn: \u0e42\u0e2d\u0e40\u0e04\u0e40\u0e23\u0e32\u0e2b\u0e32\u0e22\u0e40\u0e2d\u0e07\u0e01\u0e47\u0e44\u0e14\u0e49 https://t.co/91EWwfq22g"
#     }
# }
# {
#     "data": {
#         "id": "1509159354796228616",
#         "text": "Love thou the rose yet leave i.\n https://t.co/oBkaSKqF4o"
#     }
# }
# {
#     "data": {
#         "id": "1509159354787786762",
#         "text": "\ud83d\ude1d\ud83d\udc67\ud83c\udf3a\ud83c\udf1b https://t.co/6UImy4tpfT"
#     }
# }
# {
#     "data": {
#         "id": "1509159354770989061",
#         "text": "\u0e08\u0e23\u0e34\u0e07\u0e46 \u0e42\u0e14\u0e22\u0e2a\u0e48\u0e27\u0e19\u0e15\u0e31\u0e27\u0e14\u0e34\u0e09\u0e31\u0e19\u0e40\u0e1b\u0e47\u0e19\u0e04\u0e19\u0e01\u0e27\u0e19\u0e15\u0e35\u0e19\u0e04\u0e48\u0e30 55555555"
#     }
# }
# {
#     "data": {
#         "id": "1509159354787848194",
#         "text": "https://t.co/WpM9eKUIJi https://t.co/h7JPlV8I61"
#     }
# }
# {
#     "data": {
#         "id": "1509159354766966791",
#         "text": "RT @SamRoche22: Any takers for my fuzzy hole? https://t.co/ZQsFwZy3SC"
#     }
# }
# {
#     "data": {
#         "id": "1509159354800377856",
#         "text": "@komurokei2021 https://t.co/LwQwYzeO2t"
#     }
# }
# {
#     "data": {
#         "id": "1509159354779402245",
#         "text": "Real love begins where nothing https://t.co/gzndssDC4X"
#     }
# }
# {
#     "data": {
#         "id": "1509159354800345089",
#         "text": "RT @shivi_supremacy: Writers ne scene likhdiya... Actors ne scene shoot bhi kiya.. But how come it didn't come in telecast.. @Sphere_origin\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354800349188",
#         "text": "@uniuniuni0127 \u53ef\u611b\u3059\u304e\u308b\u2763\ufe0f"
#     }
# }
# {
#     "data": {
#         "id": "1509159354766876675",
#         "text": "@eldiarioes @albert_poux Si fuera de la PSOE o Unidas Podemos callar\u00edais como pvtas, hijos de la GP."
#     }
# }
# {
#     "data": {
#         "id": "1509159354800480260",
#         "text": "RT @Izwe_Lethu_2020: BRICS Countries must start trading their Minerals in their currencies and not US Dollars. This will end the Western Do\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354796290059",
#         "text": "RT @vivendonoff: ora ora se n\u00e3o s\u00e3o as consequ\u00eancias das minhas pr\u00f3prias atitudes"
#     }
# }
# {
#     "data": {
#         "id": "1509159354792128515",
#         "text": "@CNN https://t.co/dj2Zx9p9Rn"
#     }
# }
# {
#     "data": {
#         "id": "1509159354792296451",
#         "text": "\u5927\u962a\u306f\u591c\u685c\u304c\u7dba\u9e97\u3067\u3059\uff01 https://t.co/Xra5xce6oX"
#     }
# }
# {
#     "data": {
#         "id": "1509159358965649409",
#         "text": "@56QcGa4cRlRJSxw \u3063\u2026\u305d\u3001\u305d\u3046\u3067\u3059\u306d\u2026\u2661\u2661(\u56c1\u304b\u308c\u308c\u3070\u30d4\u30af\u3063\u3066\u53cd\u5fdc\u3057\u3061\u3083\u3063\u3066\u3001\u6271\u304f\u30b9\u30d4\u30fc\u30c9\u5c11\u3057\u3060\u3051\u65e9\u304f\u306a\u3063\u3061\u3083\u3046)"
#     }
# }
# {
#     "data": {
#         "id": "1509159358977884160",
#         "text": "RT @GreeshmaShukla: RT if you want @Tejasvi_Surya to be arrested for attacking CM house in delhi. https://t.co/UWS8oDu1dy"
#     }
# }
# {
#     "data": {
#         "id": "1509159358961233930",
#         "text": "RT @min2nr: \u30b7\u30e7\u30a6\u30ab\u8a95\u751f\u65e5\u304a\u3081\u3067\u3068\u3046\u301c\uff01\n\u30ea\u30f3\u30c9\u30a6\u306b\u8272\u3093\u306a\u6240\u9023\u308c\u3066\u3066\u3063\u3066\u3082\u3089\u3063\u3066\u304f\u308c\u3088\u306a\n(\u3053\u306e\u7d75\u306f\u30b2\u30fc\u30bb\u30f3\u3067\u30ea\u30f3\u30c9\u30a6\u306b\u306b\u3083\u3093\u30bf\u30f3\u53d6\u3063\u3066\u3082\u3089\u3063\u305f\u30b7\u30e7\u30a6\u30ab)\n\n#\u685c\u97f3\u7d2b\u967d\u82b1\u751f\u8a95\u796d\n#\u3059\u3070\u305b\u304b https://t.co/sJm3b45H1Y"
#     }
# }
# {
#     "data": {
#         "id": "1509159358961229831",
#         "text": "@donaldugbana The Raffle ticket \ud83c\udf9f\ufe0f is sent, and should be in your OpenSeas under \"Hidden\" Congrats! \ud83d\ude80"
#     }
# }
# {
#     "data": {
#         "id": "1509159358974029826",
#         "text": "@achan_main \u30a2\u30a4\u30b9\u30b1\u30fc\u30ad\u98df\u3079\u308b(\u02f6\u00b0\u0e05\u00b0\u02f6)\ud83c\udf68\ud83d\udc97\n\n\u91ce\u7403\u306f\u5144\u304c\u3057\u3066\u305f\u304b\u3089\n\u5c0f\u3055\u3044\u9803\u306f\u3088\u304f\u5fdc\u63f4\u884c\u3063\u3066\u305f\ud83e\udd2d\u26be\n\u305d\u3053\u306e\u30a4\u30aa\u30f3\u3088\u304f\u884c\u304f\u304b\u3089\n\u4eba\u591a\u3044\u6642\u306f\u91ce\u7403\u304bLIVE\u306e\u65e5\u304b\n\u3059\u3050\u5206\u304b\u308b\ud83e\udd70w\n\u5916\u3067\u98f2\u3080\u30d3\u30fc\u30eb\u7d76\u5bfe\n\u7f8e\u5473\u3057\u3044(\uff35 '\u1d17'  )\u2283\u2501\u2501*.\u2661\uff9f"
#     }
# }
# {
#     "data": {
#         "id": "1509159358994993160",
#         "text": "RT @vvvktp965: \u0e04\u0e34\u0e14\u0e16\u0e36\u0e07\u0e01\u0e32\u0e23\u0e19\u0e31\u0e48\u0e07\u0e14\u0e49\u0e27\u0e22\u0e01\u0e31\u0e19\u0e41\u0e1a\u0e1a\u0e44\u0e21\u0e48\u0e40\u0e27\u0e49\u0e19\u0e0a\u0e48\u0e2d\u0e07\u0e44\u0e1f\ud83d\ude0d\ud83d\ude0d\n\n#\u0e04\u0e34\u0e14\u0e16\u0e36\u0e07\u0e01\u0e47\u0e2d\u0e15\u0e23\u0e34\u0e0a\u0e0a\u0e35\u0e48\u0e21\u0e32\u0e01\u0e23\u0e39\u0e49\u0e22\u0e31\u0e07\nGXXOD RICHY MISS U SO MUCH https://t.co/oYOrcva2nI"
#     }
# }
# {
#     "data": {
#         "id": "1509159358969495559",
#         "text": "RT @ai7_egctky: \u9031\u306e\u771f\u3093\u4e2d\u6c34\u66dc\u65e5\u304c\u3053\u3093\u306a\u306b\u697d\u3057\u307f\u3060\u3063\u305f\u306e\u306f\u30d6\u30af\u30ed3\u4eba\u306e\u304a\u304b\u3052\u3067\u3059\uff01\n\u6182\u9b31\u306a\u65e5\u3082\u5143\u6c17\u8cb0\u3048\u307e\u3057\u305f\ud83d\ude2d\n3\u4eba\u3067\u306e\u30d1\u30d5\u30a9\u30fc\u30de\u30f3\u30b9\u306f\u307e\u3055\u306b\u30e9\u30a4\u30d6\u3067\u6700\u5f8c\u306eIWGP\u6d99\u51fa\u3066\u304d\u307e\u3057\u305f\u3002\n\u3053\u306e\u756a\u7d44\u306e\u304a\u304b\u3052\u3067\u3088\u308aHIPHOP\u304c\u5927\u597d\u304d\u306b\u306a\u308a\u307e\u3057\u305f\n\u6634\u304f\u3093\u5929\u3061\u3083\u3093\u6625\u304f\u3093U-\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159358986264589",
#         "text": "@koukititops \u7121\u8336\u82e6\u8336\u53ef\u611b\u3044\u58f0\u51fa\u3066\u305d\u3046"
#     }
# }
# {
#     "data": {
#         "id": "1509159358957256704",
#         "text": "@GC_ChromVL \u304a\u75b2\u308c\u69d8\u3067\u3057\u305f\ud83d\ude0c\u53c2\u52a0\u3067\u304d\u3066\u3068\u3066\u3082\u697d\u3057\u304b\u3063\u305f\u3067\u3059\uff01\u7b2c\u4e8c\u56de\u3082\u697d\u3057\u307f\u306b\u3057\u3066\u3044\u307e\u3059\u301c\ud83d\udcb0\u2615\ufe0f"
#     }
# }
# {
#     "data": {
#         "id": "1509159358990589962",
#         "text": "RT @g00d_drugs_: czy wy tez macie wrazenie, ze ka\u017cdy jest dzisiaj jakis odklejony? XDDDD"
#     }
# }
# {
#     "data": {
#         "id": "1509159358977888256",
#         "text": "RT @chaimin5970: \u0e27\u0e2d\u0e19\u0e08\u0e34\u0e19\u0e14\u0e39\u0e2a\u0e39\u0e49\u0e0a\u0e35\u0e27\u0e34\u0e15\u0e21\u0e32\u0e015555555555555555555555555555555555 https://t.co/zTQdwrIOsY"
#     }
# }
# {
#     "data": {
#         "id": "1509159358961172484",
#         "text": "Lo peor del manotazo q le da will no es el manotazo es q ser\u00e1 recordado por ello y no por ser el ganador del Oscar"
#     }
# }
# {
#     "data": {
#         "id": "1509159358977875972",
#         "text": "RT @seoxideep: \u0e2a\u0e30\u0e40\u0e15\u0e40\u0e14\u0e35\u0e4b\u0e22\u0e27\u0e19\u0e35\u0e49\u0e21\u0e31\u0e19\u0e44\u0e1b\u0e15\u0e35\u0e01\u0e31\u0e1a\u0e40\u0e08\u0e19\u0e2d\u0e37\u0e48\u0e19\u0e41\u0e25\u0e49\u0e27 \u0e44\u0e21\u0e48\u0e15\u0e35\u0e01\u0e30\u0e40\u0e08\u0e19\u0e2a\u0e35\u0e48 \u0e40\u0e14\u0e2d\u0e30\u0e1a\u0e35\u0e40\u0e2d\u0e17\u0e34\u0e19\u0e35\u0e40\u0e23\u0e35\u0e22\u0e01\u0e21\u0e31\u0e19\u0e44\u0e21\u0e48\u0e2b\u0e31\u0e19\u0e41\u0e25\u0e49\u0e27 \u0e41\u0e22\u0e48\u0e2d\u0e48\u0e30 \u0e04\u0e34\u0e14\u0e16\u0e36\u0e07\u0e41\u0e01\u0e4a\u0e07\u0e04\u0e4c\u0e2a\u0e32\u0e21\u0e41\u0e21\u0e48\u0e04\u0e23\u0e31\u0e27"
#     }
# }
# {
#     "data": {
#         "id": "1509159358990626818",
#         "text": "@FIFAWorldCup @ghanafaofficial #replay_match_algeria_cameron"
#     }
# }
# {
#     "data": {
#         "id": "1509159358986338305",
#         "text": "RT @lalaleo0: Ngakak sih liat tl \ud83e\udd23\n\nWE LOVE YOU LISA \n\n#ROS\u00c9fansApologizeToLISA"
#     }
# }
# {
#     "data": {
#         "id": "1509159358973808641",
#         "text": "RT @AmiraYe87226581: \u0627\u0644\u0645\u0631\u0636 \u0648\u0627\u0644\u0645\u0633\u062a\u0634\u0641\u064a\u0627\u062a \u0642\u0627\u0633\u064a\u064a\u0646 \u062c\u062f\u0627 \u0628\u0627\u0644\u0630\u0627\u062a \u0639\u0644\u064a \u0643\u0628\u0627\u0631 \u0627\u0644\u0633\u0646\u060c \u0627\u0646\u0627 \u0628\u062a\u0645\u0646\u064a \u0627\u0646\u064a \u0644\u0645\u0627 \u0627\u0645\u0648\u062a \u0627\u0645\u0648\u062a \u0645\u0648\u062a\u0629 \u062e\u0641\u064a\u0641\u0647\u060c \u0628\u0633\u0644\u0627\u0645\u060c \u0628\u062f\u0648\u0646 \u0645\u0639\u0627\u0646\u0627\u0629 \u0627\u0648 \u0623\u0644\u0645"
#     }
# }
# {
#     "data": {
#         "id": "1509159358965420039",
#         "text": "RT @VillarPaulo17: Um recadinho do velho Olavo de Carvalho para os sumidos C\u00e1ssio Nunes e Andr\u00e9 Mendon\u00e7a. \" A modera\u00e7\u00e3o na defesa da verdad\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159358957035530",
#         "text": "@Vafa78067151 \ud83d\ude0d"
#     }
# }
# {
#     "data": {
#         "id": "1509159358961176587",
#         "text": "RT @Simo10_des: \u0627\u0645\u062a\u0644\u0643 \u0645\u0643\u0627\u0646\u0629 \u0645\u0645\u064a\u0632\u0629 \u0628\u064a\u0646 \u0645\u0646\u0627\u0641\u0633\u064a\u0643 \u0628\u0634\u0639\u0627\u0631 \u0645\u0645\u064a\u0632 \u0648\u0647\u0648\u064a\u0629 \u062c\u0630\u0627\u0628\u0629 \u0644\u0639\u0645\u0644\u0627\u0626\u0643\ud83d\udc99\ud83d\udc9b\u2b1c\n\u0627\u0637\u0644\u0628:\n\u062a\u0635\u0645\u064a\u0645 \u0644\u0648\u0642\u0648 \u0634\u0639\u0627\u0631\u0627\u062a    - \u062a\u0635\u0645\u064a\u0645 \u0647\u0648\u064a\u0629 \u062a\u062c\u0627\u0631\u064a\u0629\n\u062a\u0635\u0645\u064a\u0645 \u0628\u0648\u0633\u062a\u0627\u062a\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159358957080578",
#         "text": "RT @hamza_tweets17: \u06cc\u0627 \u0627\u0644\u0644\u06c1 \u0645\u06cc\u0631\u06d2 \u0645\u0644\u06a9 \u06a9\u06cc \u0645\u06cc\u0631\u06d2 \u0648\u0632\u06cc\u0631\u0627\u0639\u0638\u0645 \u06a9\u06cc \u062d\u0641\u0627\u0638\u062a \u06a9\u0631\u0646\u0627 \n#COAS\n#\u06c1\u0631_\u0633\u0627\u0632\u0634_\u06c1\u0648\u06af\u06cc_\u0646\u0627\u06a9\u0627\u0645 https://t.co/DNQiu34qce"
#     }
# }
# {
#     "data": {
#         "id": "1509159358990811140",
#         "text": "@sxs__mh \u3061\u3087\u3046\u3069\u3044\u3044\u771f\u3093\u4e2d\u3044\u306a\u3044\u308f\u3051\uff1f\uff1f\uff1f\uff1f\uff1f\u3061\u3087\u3046\u3069\u3044\u3044\u3068\u3053\u3067\u304d\u306a\u3044\u306e\u304b\u306d\u2026\uff1f\uff1f\uff1f\uff1f"
#     }
# }
# {
#     "data": {
#         "id": "1509159358961455108",
#         "text": "@dmchan_bom2 \u305b\u3084\u306a\uff01\u5f85\u3063\u3066\u308b\ud83e\udd7a"
#     }
# }
# {
#     "data": {
#         "id": "1509159358994788358",
#         "text": "@kafa10milyon500 Yok 14"
#     }
# }
# {
#     "data": {
#         "id": "1509159358969655302",
#         "text": "@mikejason73 @VirginiaDMV Thots &amp; prayers 2 U"
#     }
# }
# {
#     "data": {
#         "id": "1509159358990786560",
#         "text": "@sy17marvel\n\u8a3a\u65ad\u7d50\u679c\u306f\u2026\n\n\u3010\u95c7\u5ea6\uff1a\ud83c\udf14\ud83c\udf15\ud83c\udf15\ud83c\udf15\ud83c\udf15\u3011\n\u3042\u306a\u305f\u306f\u30ea\u30fc\u30c0\u30fc\u30b7\u30c3\u30d7\u3068\u60c5\u71b1\u306b\u3042\u3075\u308c\u3001\u3044\u3064\u3082\u524d\u5411\u304d\ud83d\udcab\u305d\u3093\u306a\u3042\u306a\u305f\u306b\u306f\u3001\u307b\u3068\u3093\u3069\u95c7\u304c\u6f5c\u3093\u3067\u3044\u306a\u3044\u304b\u3082\u2049\ufe0f\u26a1\n\n\u6e29\u539a\u3067\u81c6\u75c5\u306a\u7537\u306b\u6f5c\u3080\u201c\u95c7\u201d\u304b\u3089\u751f\u307e\u308c\u305f\u3001\u30c0\u30fc\u30af\u30fb\u30d2\u30fc\u30ed\u30fc\u306e\u7269\u8a9e\ud83c\udf19\n\n\u300e\u30e0\u30fc\u30f3\u30ca\u30a4\u30c8\u300f\u6bce\u9031\u6c34\u66dc #\u30c7\u30a3\u30ba\u30cb\u30fc\u30d7\u30e9\u30b9 \u3067\u72ec\u5360\u914d\u4fe1\ud83d\udcfa https://t.co/LgSsYi8L4V"
#     }
# }
# {
#     "data": {
#         "id": "1509159358957035528",
#         "text": "RT @paulomcdsousa: \u2764\ufe0f\ud83d\udda4 https://t.co/ZwnW3Cix6E"
#     }
# }
# {
#     "data": {
#         "id": "1509159358969835523",
#         "text": "@kaseewa_12 \u30d5\u30a9\u30ed\u30fc\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\uff01\uff01\n\n\u3088\u308d\u3057\u304f\u304a\u9858\u3044\u3044\u305f\u3057\u307e\u3059\uff01\uff01\n\n\u30d5\u30e9\u30f3\u3061\u3083\u3093\u30a6\u30d5\u30d5"
#     }
# }
# {
#     "data": {
#         "id": "1509159358956900352",
#         "text": "RT @catmiwo: So pretty\ud83e\udd0d\u2728 https://t.co/LoE2RXRrXo"
#     }
# }
# {
#     "data": {
#         "id": "1509159358986584064",
#         "text": "@Guerrilla Pls fix the second verse bug..i can meet zo in the plain song after i finished the main quests @Guerrilla."
#     }
# }
# {
#     "data": {
#         "id": "1509159358990635008",
#         "text": "@therealstrnad @srna_jan Se\u0161 moc cringe"
#     }
# }
# {
#     "data": {
#         "id": "1509159358956941316",
#         "text": "@ayaraaphile Anti jamet"
#     }
# }
# {
#     "data": {
#         "id": "1509159358990811136",
#         "text": "RT @jooheonspace: Jooheon is such a momma\u2019s boy, he sees everything and reminds of her, he is such a good son \ud83e\udd7a #\uc8fc\ud5cc https://t.co/B1wswDNYe2"
#     }
# }
# {
#     "data": {
#         "id": "1509159358969499651",
#         "text": "@ngopidulslah nggak slmt ovt"
#     }
# }
# {
#     "data": {
#         "id": "1509159358965317638",
#         "text": "\u3054\u3061\ud83d\ude4f https://t.co/kjrYZ8dkMQ"
#     }
# }
# {
#     "data": {
#         "id": "1509159358978211846",
#         "text": "RT @B_Moeko: \u30ab\u30fc\u30d3\u30a3\u3055\u3093\u2192\u30d4\u30f3\u30af\u306e\u60aa\u9b54\u304c\u8df3\u306d\u308b\u6642\u3002\u5f37\u8005\u3069\u3082\u7686\u5875\u306b\u540c\u3058\uff08\u8981\u7d04:\u3053\u3044\u3064\u304c\u52d5\u3044\u305f\u3089\u6b7b\u306c\uff09\n\n\u30e1\u30bf\u30ca\u30a4\u30c8\u3055\u3093\u2192\u5272\u3068\u732a\u7a81\u731b\u9032\u306a\u306e\u3067\u4e0a\u624b\u3044\u3053\u3068\u52d5\u304d\u3092\u5c01\u3058\u305f\u3089\u3069\u3046\u306b\u304b\u306a\u308b\u3002\u305d\u3046\u3067\u3082\u3057\u306a\u3044\u3068\u65ac\u3089\u308c\u308b\u3002\n\n\u5927\u738b\u69d8\u2192\u4e0d\u610f\u6253\u3061\u3067\u5012\u3055\u306a\u3044\u3068\u7121\u8336\u82e6\u8336\u7b56\u3092\u7df4\u3089\u308c\u308b\u3002\n\n\u3064\u304a\u3044\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1509159358957240326",
#         "text": "@otsukisama__o #\u30c7\u30b8\u30dbTwitter\u30de\u30fc\u30c1CP \u3078\u306e\u3054\u53c2\u52a0\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\n\u62bd\u9078\u7d50\u679c\u306f\u753b\u50cf\u3092\u30c1\u30a7\u30c3\u30af\u2728\n\n\u30ad\u30e3\u30f3\u30da\u30fc\u30f3\u306f3\u670831\u65e5(\u6728)\u307e\u3067\u958b\u50ac\u4e2d\u3067\u3059\ud83c\udf81\ud83d\udc95\n\u6bce\u65e51\u56de\u53c2\u52a0\u3067\u304d\u307e\u3059\u3088\ud83e\udd70\n\n\u25bc\u4e00\u6b69\u3075\u307f\u3060\u3059\u4fdd\u967a #\u30c7\u30b8\u30db \u306e\u8a73\u7d30\u306f\u3053\u3061\u3089\nhttps://t.co/olUncH4Big https://t.co/Oxca1Virwe"
#     }
# }
# {
#     "data": {
#         "id": "1509159358965243906",
#         "text": "RT @amatawith: \u6c17\u5206\u304c\u3044\u3044\u306e\u3067\u2606\n3/30 \u6c34\u66dc\u65e521\u6642\u3006\n\u62bd\u9078\u3063\u305f\u30fc\u4f7f\u7528\n\u5f15\u7528\u53d6\u5f97\u8a2d\u5b9a\n\u79c1\u306e\u30d5\u30a9\u30ed\u30fc&amp;\u3053\u306e\u30c4\u30a4\u30fc\u30c8RT\n\u5f53\u9078\u54c1A500\n\u5f53\u9078\u80051\u540d\u69d8\n\u203b\u5b9f\u7e3e\u3064\u3051\u3066\u306e\u53d7\u3051\u53d6\u308a\u30c4\u30a4\u30fc\u30c8\u3067\u304d\u308b\u4eba\n#\u61f8\u8cde\n#\u30d7\u30ec\u30bc\u30f3\u30c8\u4f01\u753b\n#Amazon https://t.co/x6\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159358974009344",
#         "text": "@RfKcbn \ub098\uce30\u3154\uc774\uc694!"
#     }
# }
# {
#     "data": {
#         "id": "1509159358965248000",
#         "text": "Tag \u51fa\u3057\u305f\u306e\u3067\u56de\u3057\u3066\u8cb0\u3048\u305f\u3089\u559c\u3073\u307e\u3059\u3001\u3001\u3001\u3001\ud83d\ude3f\ud83d\udc96"
#     }
# }
# {
#     "data": {
#         "id": "1509159338006482958",
#         "text": "@rpancost Yes\u2026 though I did that thing where you can see how much your pension is reduced by and mine was a weep fest\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159358977875974",
#         "text": "@BeateHeart \u0e2d\u0e22\u0e32\u0e01\u0e01\u0e34\u0e19\u0e19\u0e21\u0e27\u0e31\u0e27"
#     }
# }
# {
#     "data": {
#         "id": "1509159358994989057",
#         "text": "RT @MeowedOfficial: When the catnip hits\n\n#meowed #meowedofficial #TheMeowedClub https://t.co/MQPAYbeRHY"
#     }
# }
# {
#     "data": {
#         "id": "1509159358982410240",
#         "text": "\u6700\u8fd1\u65b0\u3057\u3044\u7d75\u3092\u63cf\u3051\u3066\u3044\u306a\u3044\u306e\u3067\u3001Instagram\u3067\u3053\u308c\u307e\u3067\u306e\u7d75\u306e\u30e1\u30a4\u30ad\u30f3\u30b0\u516c\u958b\u3057\u3066\u3044\u307e\u3059\u3002\n\u6c17\u304c\u5411\u3044\u305f\u3089\u6687\u3064\u3076\u3057\u306b\u3067\u3082\u898b\u3066\u307f\u3066\u304f\u3060\u3055\u3044\u301c\uff01\nhttps://t.co/QD27FgB62i"
#     }
# }
# {
#     "data": {
#         "id": "1509159358986395648",
#         "text": "RT @milfitaly: se ti va di giocare con me scrivimi https://t.co/DLZOACBnME"
#     }
# }
# {
#     "data": {
#         "id": "1509159358961119235",
#         "text": "re,\u0e41\u0e25\u0e01\u0e1f\u0e2d\u0e25 #imgambts"
#     }
# }
# {
#     "data": {
#         "id": "1509159358965370886",
#         "text": "RT @Faktillon: Die besten Fakten als Buch, Kalender oder T-Shirt \ud83d\udc49 https://t.co/kfNylUn9H6\nEhrliche Nachrichten auf \ud83d\udc49 https://t.co/uR45PLsC\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159358982148100",
#         "text": "RT @TanakaShumba04: Some girls be like, \u201cI can\u2019t cook because my mum didn\u2019t teach me.\u201d\n\nWho taught you 69?"
#     }
# }
# {
#     "data": {
#         "id": "1509159358986215424",
#         "text": "\u30d8\u30d6\u30d0\u30f3\u3063\u3066\uff13\u51f8\u306e\u6709\u7121\u3067\u8a55\u4fa1\u304c\u4e00\u6c17\u306b\u5909\u308f\u308b\u30ad\u30e3\u30e9\u304c\u3044\u308b\u306e\u3060\u3051\u3069\u3001tier\u51fa\u3059\u306a\u3089\u7121\u51f8\uff08\u307e\u305f\u306f\uff11\u51f8\uff09\u3068\uff13\u51f8\u3067\u5206\u3051\u3066\u51fa\u3059\u304b\u3057\u305f\u65b9\u304c\u3044\u3044\u3068\u601d\u3046\n\n\u51f8\u6570\u3067\u5206\u3051\u3066\u306a\u3044\u3068\u304b\u3001\u8a55\u4fa1\u9805\u76ee\u306b\u5165\u308c\u3066\u306a\u3044tier\u306f\u3042\u307e\u308a\u4fe1\u3058\u3066\u306f\u3044\u3051\u306a\u3044\n\n#\u30d8\u30d6\u30d0\u30f3"
#     }
# }
# {
#     "data": {
#         "id": "1509159358990786561",
#         "text": "@acabiasaaja yang bener aja"
#     }
# }
# {
#     "data": {
#         "id": "1509159358961225736",
#         "text": "@0xhss \u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647\u0647"
#     }
# }
# {
#     "data": {
#         "id": "1509159358978043904",
#         "text": "gosto muito que meu dix virou um armaz\u00e9m de v\u00eddeos aleat\u00f3rios pls \u00e9 tipo meu twitter, mas no instagram https://t.co/g5mnICWquQ"
#     }
# }
# {
#     "data": {
#         "id": "1509159358965469185",
#         "text": "RT @Sc7Ya: @nomercy_47 \u0648\u0627\u0644\u0644\u0647 \u0627\u0646\u0646\u0627 \u0645\u062d\u0633\u0648\u062f\u064a\u0646 \u0641\u064a\u0643 \u0648\u0628\u0627\u0645\u062b\u0627\u0644\u0643 \u064a\u0627\u0628\u0648 \u0639\u0628\u062f\u0627\u0644\u0644\u0647 \u060c\u060c \u062d\u062a\u0649 \u0644\u0648 \u062c\u062d\u0641\u0644\u0646\u0627 \u0628\u0643\u0631\u0647 \u0645\u0636\u0627\u0631\u0628 \u0627\u0644\u0633\u0647\u0645 \u0644\u0643\u0646 \u064a\u0643\u0641\u064a \u0627\u0646\u0643 \u0631\u0627\u0647\u0646\u062a \u0639 \u0633\u0647\u0645 \u0645\u062d\u0642\u0642 \u0627\u0631\u0628\u0627\u062d \u0648\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159358973857795",
#         "text": "RT @skereunpesado: https://t.co/qMMLSRsVwm"
#     }
# }
# {
#     "data": {
#         "id": "1509159358973693955",
#         "text": "Maldives Operative Cheese fuchsia Cambridgeshire purple Brand Dollar transparent Carolina bypassing withdrawal https://t.co/4iJ8VKYagu"
#     }
# }
# {
#     "data": {
#         "id": "1509159358961438725",
# ...
#     }
# }
# {
#     "data": {
#         "id": "1509159358982402048",
#         "text": "@kento_0304_ \u304c\u3093\u3070\u308c\u308b\u3046\u3046\u3046\u3046\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1509159375759368200",
#         "text": "@ata_pin \u0432\u043e\u043e\u0431\u0449\u0435 \u044d\u0442\u043e \u0436\u0435 \u0441\u0432\u0438\u043d\u0441\u0442\u0432\u043e"
#     }
# }
# {
#     "data": {
#         "id": "1509159358965460995",
#         "text": "rien ! exactement https://t.co/8xvQCGJMGi"
#     }
# }
# {
#     "data": {
#         "id": "1509159354792136706",
#         "text": "@AlejandroP_89 @LucybellHaner \ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02\ud83d\ude02"
#     }
# }
# {
#     "data": {
#         "id": "1509159375747031048",
#         "text": "\u307e\u3042\u30b9\u30ea\u30b6\u30ea\u30aa\u3084\u3063\u3066\u308b\u3084\u3064\u306b\u306f\u95a2\u4fc2\u306a\u3044\u3067\u3057\u3087 #\u30cb\u30c8\u30b9\u30da"
#     }
# }
# {
#     "data": {
#         "id": "1509159375738314761",
#         "text": "RT @Delavegalaw: @gtconway3d Actually, it's evidence of criminal intent while engaged in the crime itself. Evidence showing consciousness o\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375771865088",
#         "text": "RT @BTSdailyinfo: [PHOTO] 220330 @BTS_twt\n \nHYBE and Bang Si-hyuk Are Transforming the Music Business\u2014With a Little Help From BTS (2/2)\n\n\ud83d\udd17\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375767838723",
#         "text": "RT @leemimo19: \u0625\u0646 \u0647\u0645\u0643 \u0643\u0646\u062a \u0628\u062d\u0627\u062c\u062a\u0647\u0645 .\" \u0644\u0623\u0646\u0646\u0627\n\nhttps://t.co/05oPKJ6DUW"
#     }
# }
# {
#     "data": {
#         "id": "1509159375738634243",
#         "text": "RT @jaeedimples: YY\ud83d\udcad: https://t.co/Zl3L0BVjKp"
#     }
# }
# {
#     "data": {
#         "id": "1509159375742537729",
#         "text": "RT @UnderbedDara: \u0e25\u0e39\u0e01\u0e2a\u0e32\u0e27\u0e21\u0e32\u0e41\u0e25\u0e49\u0e27\u0e08\u0e49\u0e32\u0e32\u0e32\u0e32\u0e32\u0e32 \n\n\u0e2b\u0e25\u0e31\u0e07\u0e08\u0e32\u0e01\u0e2d\u0e38\u0e1a\u0e0a\u0e37\u0e48\u0e2d\u0e21\u0e32\u0e19\u0e32\u0e19 \u0e27\u0e31\u0e19\u0e19\u0e35\u0e49\u0e41\u0e21\u0e48 #\u0e0a\u0e21\u0e1e\u0e39\u0e48\u0e2d\u0e32\u0e23\u0e22\u0e32  \u0e21\u0e32\u0e40\u0e09\u0e25\u0e22\u0e41\u0e25\u0e49\u0e27\u0e27\u0e48\u0e32\u0e19\u0e49\u0e2d\u0e07\u0e0a\u0e37\u0e48\u0e2d\u0e2d\u0e32\u0e1a\u0e34\u0e40\u0e01\u0e25 \u0e21\u0e32\u0e08\u0e32\u0e01\u0e0a\u0e37\u0e48\u0e2d\u0e1e\u0e32\u0e22\u0e38\u0e43\u0e19\u0e1b\u0e35 2015 \u0e17\u0e35\u0e48\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375734448131",
#         "text": "RT @Amirazennie: #LISA 0327 photobook vol.3 wallpaper/lockscreen |extended [long &amp; short sizes]\n\nscan cr. @i60808 #\ub9ac\uc0ac #BLACKPINK https://t.\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375763800064",
#         "text": "RT @Area53network: AIRDROP CAMPAIGN 2 KICK OFF\n\nTo express our deepest gratitude for  #Area53 citizens support and trust, we are running a\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375751249922",
#         "text": "RT @YahooNewsTopics: \u3010\u982d\u9aea\u306e\u30b8\u30e7\u30fc\u30af \u82e6\u3057\u3080\u8131\u6bdb\u75c7\u60a3\u8005\u3011\nhttps://t.co/1go7DJd9SG\n\n\u8131\u6bdb\u75c7\u3068\u306f\u3069\u306e\u3088\u3046\u306a\u75c5\u6c17\u3067\u3001\u60a3\u8005\u306f\u3069\u306e\u3088\u3046\u306a\u60a9\u307f\u3092\u6301\u3063\u3066\u3044\u308b\u306e\u304b\u3002\u5c02\u9580\u533b\u306f\u3001\u30c6\u30ec\u30d3\u3084\u30e9\u30b8\u30aa\u306a\u3069\u3067\u306e\u982d\u9aea\u306b\u307e\u3064\u308f\u308b\u300c\u30b8\u30e7\u30fc\u30af\u300d\u304c\u3001\u8131\u6bdb\u75c7\u60a3\u8005\u3092\u82e6\u3057\u3081\u308b\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159354791981064",
#         "text": "\u3072\u306a\u8a95\u796d\u6700\u9ad8\u3060\u3063\u305f\uff01\n\u6700\u521d\u304b\u3089\u6700\u5f8c\u307e\u3067\u611f\u52d5\u3057\u3063\u3071\u306a\u3057\u3060\u3063\u305f\n#\u65e5\u5411\u574246 \n#\u3072\u306a\u8a95\u796d2022 https://t.co/kARdWGms90"
#     }
# }
# {
#     "data": {
#         "id": "1509159375759364099",
#         "text": "RT @chsandhilaa: \ud83d\ude22\ud83d\ude22\ud83d\ude22\ud83d\ude22\ud83d\ude22 https://t.co/wPT1kO2eTp"
#     }
# }
# {
#     "data": {
#         "id": "1509159375767846922",
#         "text": "@MrTooDamnChris @OrangeCoSheriff @OCFireRescue oh no copper got a lil high poor baby"
#     }
# }
# {
#     "data": {
#         "id": "1509159375738310656",
#         "text": "RT @miiniyoongs: \ud83d\udc9c \u2018The End Of The F***ing World\u2019\n\ud83d\udc30 #/the end of the f***ing corona\n\n\ud83d\udc9c \u2018The adam project\u2019\n\ud83d\udc30 #/OOOOKKKK https://t.co/MmDZm5q\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375746781192",
#         "text": "RT @tokoyamitowa: \u3056\u3064\u3060\u3093\u3042\u3056\u3059\uff01\uff01\u305f\u306e\u3057\u304b\u305f\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1509159375746715653",
#         "text": "\u753b\u50cf\u6642\u306e56\u52dd19\u6557\u306e\u30ec\u30fc\u30c81994\u304b\u3089\u5927\u304d\u304f\u8ca0\u3051\u8d8a\u3057\u3066\u3057\u307e\u3063\u305f\u305f\u3081\u3001\u5927\u306e\u82e6\u624b\u306e\u6700\u7d42\u65e5\u3082\u5bfe\u6226\u3057\u3088\u3046\u3068\u601d\u3044\u307e\u3059\u3002\u671b\u307f\u8584\u306a\u3053\u3068\u306f\u5206\u304b\u3063\u3066\u3044\u307e\u3059\u304c\u3001\u3084\u308c\u308b\u3060\u3051\u3084\u3063\u3066\u307f\u305f\u3044\u3068\u601d\u3044\u307e\u3059\u3002\u76ee\u6a19\u306b\u5411\u304b\u3063\u3066\u6226\u3044\u7d9a\u3051\u308b\u7686\u3055\u3093\u3092\u898b\u7fd2\u3044\u305f\u3044\u3067\u3059\u3002 #\u30dd\u30b1\u30e2\u30f3\u5263\u76fe #NintendoSwitch https://t.co/B6glddmMid"
#     }
# }
# {
#     "data": {
#         "id": "1509159375751065602",
#         "text": "Khels c pas une rue \u00e0 stras ? https://t.co/0w71v03Cp2"
#     }
# }
# {
#     "data": {
#         "id": "1509159375763611654",
#         "text": "@ipcxn @iavp_ \u0627\u0644\u062f\u0648\u0646 \u0648\u0646\u0633\u064a\u062a \u0627\u0646\u0647 \u0645\u0639\u0637\u0648\u0628 \u0645\u0627\u064a\u062d\u062a\u0627\u062c \u064a\u0646\u0639\u0637\u0628"
#     }
# }
# {
#     "data": {
#         "id": "1509159367370809350",
#         "text": "@jhefvckk2 @bobreddit889 esse abutre \u00e9 o do mcu ze"
#     }
# }
# {
#     "data": {
#         "id": "1509159367349841922",
#         "text": "@i1Hamdan @R2jEUqQxVEnTH4y \u0645\u0628\u0631\u0648\u0643"
#     }
# }
# {
#     "data": {
#         "id": "1509159375734460416",
#         "text": "\u6c38\u4f5c\u535a\u7f8e\u306f\u6614\u304b\u3089\u5909\u308f\u3089\u306a\u3044\u7f8e\u3057\u3055"
#     }
# }
# {
#     "data": {
#         "id": "1509159375759241220",
#         "text": "RT @zee_pruk: \u0e2a\u0e39\u0e49\u0e01\u0e31\u0e19\u0e15\u0e48\u0e2d\u0e44\u0e1b\u0e40\u0e1e\u0e37\u0e48\u0e2d\u0e01\u0e32\u0e23\u0e40\u0e17\u0e48\u0e32\u0e40\u0e17\u0e35\u0e22\u0e21\u0e17\u0e35\u0e48\u0e41\u0e17\u0e49\u0e08\u0e23\u0e34\u0e07 \u0e40\u0e1b\u0e47\u0e19\u0e01\u0e33\u0e25\u0e31\u0e07\u0e43\u0e08\u0e43\u0e2b\u0e49\u0e17\u0e38\u0e01\u0e04\u0e19\u0e04\u0e23\u0e31\u0e1a #\u0e2a\u0e21\u0e23\u0e2a\u0e40\u0e17\u0e48\u0e32\u0e40\u0e17\u0e35\u0e22\u0e21"
#     }
# }
# {
#     "data": {
#         "id": "1509159375747022855",
#         "text": "https://t.co/hoFw5CnUhn"
#     }
# }
# {
#     "data": {
#         "id": "1509159375759360009",
#         "text": "@Ahsenbarlaz Selam"
#     }
# }
# {
#     "data": {
#         "id": "1509159375772217354",
#         "text": "\u521d\u6f14\u594f\u304b\u3089\u4e5d\u5e74\n#nowplaying Wing Of Hope by BRIDEAR https://t.co/jnGXK9hurD"
#     }
# }
# {
#     "data": {
#         "id": "1509159375746785284",
#         "text": "RT @CryptoGlobeInfo: \"In the eyes of traditional and institutional players [crypto] has become too big to ignore. No, it's not a fad, it's\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375750979589",
#         "text": "RT @quantlordd: the solidly /liquidity page is completely dysfunctional, good thing i\u2019m rebuilding it using subgraphs into the @DeusDao app\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375734292493",
#         "text": "RT @RBW_MAMAMOO: [#\uc194\ub77c #\ubb38\ubcc4]\n\n\uc6b0\ub9ac \ubb34\ubb34 \uc5ec\ub7ec\ubd84 Mnet 'TMI \nSHOW'\uc5d0 \uc194\ub77c\uc640 \ubb38\ubcc4\uc774 \n\ucd9c\uc5f0\ud569\ub2c8\ub2e4\u2728 \uc7a0\uc2dc \ud6c4 8\uc2dc\n\ubcf8\ubc29\uc0ac\uc218 \ub193\uce58\uc9c0 \ub9c8\uc138\uc694\u2764\ud83d\udc99\n\n#Solar #MoonByul #TMISHOW https://t.co/ZAJR\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375763832834",
#         "text": "RT @manybaht: \u0e17\u0e38 \u0e01 \u0e44 \u0e25 \u0e1f\u0e4c \u0e44 \u0e2d\u0e49 \u0e1e \u0e27 \u0e01\nhttps://t.co/iSDzcD4AHv https://t.co/EOJOrhw15L"
#     }
# }
# {
#     "data": {
#         "id": "1509159375746740231",
#         "text": "RT @kurosakiinu: \u30c8\u30ec\u30a4\u5148\u8f29\u306e\u3042\u306e\u53f0\u8a5e https://t.co/j5adO6yz8u"
#     }
# }
# {
#     "data": {
#         "id": "1509159375750852609",
#         "text": "RT @pj_sekai: \ud83c\udf1f\u30d7\u30ed\u30b8\u30a7\u30af\u30c8\u30bb\u30ab\u30a41.5\u5468\u5e74\ud83c\udf1f\n\n\u672c\u65e53\u670830\u65e5\u3067\u30d7\u30ed\u30b8\u30a7\u30af\u30c8\u30bb\u30ab\u30a4\u306f1.5\u5468\u5e74\u3092\u8fce\u3048\u307e\u3057\u305f\ud83c\udf8a\n\u3044\u3064\u3082\u5fdc\u63f4\u3044\u305f\u3060\u304d\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3059\ud83d\ude0a\u2728\n\n\u8a18\u5ff5\u30a4\u30e9\u30b9\u30c8\u306f\u30ab\u30f3\u30df\u7f36\uff08@mikanoisi_\uff09\u3055\u3093\u306b\u62c5\u5f53\u3044\u305f\u3060\u304d\u307e\u3057\u305f\ud83c\udfa8\ud83d\udcab\n\n#\u521d\u97f3\u30df\u30af #\u30d7\u30ed\u30bb\u30ab #\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375746723842",
#         "text": "RT @ku_ni_sound: No.3 \u3086\u3046\u304f\u3093\uff01\uff01\uff01\ud83d\udc9a\n\n\u3075\u308f\u3075\u308f\u30b7\u30e7\u30bf\u30dc\u3067\u304b\u308f\u3044\u3044\u3086\u3055\u3093\uff01\uff01\n\u305d\u3057\u3066\u82f1\u8a9e\u3082\u30da\u30e9\u30da\u30e9\u306a\u30ae\u30e3\u30c3\u30d7\uff01\n\n\u3053\u308c\u304b\u3089\u3082\u3088\u308d\u3057\u304f\u983c\u3080\ud83d\ude4f\u2728\n\n\u3059\u305f\u307d\u3089\u5468\u5e74\u307e\u3067\u6b8b\u308a\u308f\u305a\u304b\u2026\u2026\uff01\uff01\uff01"
#     }
# }
# {
#     "data": {
#         "id": "1509159375747031045",
#         "text": "RT @watoson_9461: \u30a2\u30de\u30ae\u30d51000\u5186\u30d7\u30ec\u30bc\u30f3\u30c8\u2757\ufe0f\n\nRT\u306e\u4e2d\u304b\u30891\u540d\u62bd\u9078\u3057\u307e\u3059\ud83d\ude04\n\n\u3006\u520724\u6642\u9593\u5f8c https://t.co/IdULzSH63M"
#     }
# }
# {
#     "data": {
#         "id": "1509159375771996160",
#         "text": "RT @geminis_hn: \ud83e\udd23\ud83e\udd23\ud83e\udd23 https://t.co/l7SAiKhMZl"
#     }
# }
# {
#     "data": {
#         "id": "1509159375767842818",
#         "text": "RT @lulucomentss: amando o carinho da doni com ela  https://t.co/T6tgaDYoJO"
#     }
# }
# {
#     "data": {
#         "id": "1509159375734251524",
#         "text": "This is the exchange every trader needs. You can trade Crypto, Forex, Commodities, Precious metals, Gas and Oil at #BlueBit. To see details you are invited in our AMA with Gokhshtein Media.\n@BlueSparrowETH \n@BluesparrowC\n@Bluebit_io\n#BlueBitIO\nhttps://t.co/HKivEbBiqF\n117 https://t.co/sEAg1NvkeW"
#     }
# }
# {
#     "data": {
#         "id": "1509159375734132736",
#         "text": "RT @Mahiseikh1: \u0644\u06d2 \u062c\u0627\u0624 \u0627\u067e\u0646\u06d2 \u062c\u06be\u0648\u0679\u06d2 \u0648\u0639\u062f\u06d2\n\u0627\u06af\u0644\u06d2 \u0639\u0634\u0642 \u0645\u06cc\u06ba \u062a\u0645\u06c1\u06cc\u06ba \u0636\u0631\u0648\u0631\u062a \u067e\u0691\u06d2 \u06af\u06cc\n\n#\u0627\u0631\u062f\u0648_\u0632\u0628\u0627\u0646"
#     }
# }
# {
#     "data": {
#         "id": "1509159375759622145",
#         "text": "RT @kavitha_priyan: \u0b95\u0bb0\u0bc1\u0ba3\u0bbe\u0ba8\u0bbf\u0ba4\u0bbf \u0b8e\u0ba9\u0bcd\u0bb1\u0bc1 \u0b9a\u0bca\u0bb2\u0bcd\u0bb2\u0bbe\u0ba4\u0bc0\u0bb0\u0bcd\u0b95\u0bb3\u0bcd \u0b95\u0bb2\u0bc8\u0b9e\u0bb0\u0bcd \u0b8e\u0ba9\u0bcd\u0bb1\u0bc1 \u0b9a\u0bca\u0bb2\u0bcd\u0bb2\u0bc1\u0b99\u0bcd\u0b95\u0bb3\u0bcd. \u0ba4\u0bb2\u0bc8\u0bb5\u0bb0\u0bcd \u0bb8\u0bcd\u0b9f\u0bbe\u0bb2\u0bbf\u0ba9\u0bcd \u0b8e\u0ba9\u0bcd\u0ba9 \u0b92\u0bb0\u0bc1 style!\u0b85\u0ba3\u0bcd\u0ba3\u0ba9\u0bcd \u0b89\u0ba4\u0baf\u0ba8\u0bbf\u0ba4\u0bbf - \u0ba4\u0bcb\u0bb4\u0bb0\u0bcd \u0bb0\u0bbe\u0b9c\u0bc0\u0bb5\u0bcd\u0b95\u0bbe\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1509159375734149121",
#         "text": "\u307e\u3063\u3066\u65e5\u672c\u8a9e\u4e0b\u624b\u304f\u305d\u3059\u304e\u3093"
#     }
# }
# {
#     "data": {
#         "id": "1509159375742640130",
#         "text": "Oh yeah. 1TB. \ud83e\udd73 #PS5#PS5Share https://t.co/N29lOcc6cI"
#     }
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-af70a55c11f1> in <module>()
#       2 timeout = 0
#       3 while True:
# ----> 4     connect_to_endpoint(url)
#       5     timeout += 1
#       6
#
# <ipython-input-11-830756d6cb01> in connect_to_endpoint(url)
#       2     response = requests.request("GET", url, auth=bearer_oauth, stream=True)
#       3     print(response.status_code)
# ----> 4     for response_line in response.iter_lines():
#       5         if response_line:
#       6             json_response = json.loads(response_line)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     802         pending = None
#     803
# --> 804         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     805
#     806             if pending is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Filtered Stream
#
# We will now see how to get tweets based on certain rules using FilteredStream. Tweets are requested from the URL [SearchStreamURL](https://developer.twitter.com/en/docs/twitter-api/tweets/filtered-stream/api-reference/get-tweets-search-stream) <br>
#
# - You can adjust the rules by changing sample_rules under the set_rules function.
# - Here the rules are getting tweets with cat and dog text and images.
#   - The "has" operator will get tweets that are only associated with images.
#   - the "tag" operator is just a string which can be used at a high level to recognize the rule.
# - get_stream prints out the tweets retrieved according to the rules from the filtered stream end point.
# - Once you connect to the FilteredStream endpoint you will keep getting tweets matching the rules through a continuous http streaming connection.
# - Check out [BuildRules](https://developer.twitter.com/en/docs/twitter-api/tweets/filtered-stream/integrate/build-a-rule) for more details on building rules for the filtered stream endpoint.

# %%
def get_rules():
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream/rules", auth=bearer_oauth
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot get rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))
    return response.json()

def delete_all_rules(rules):
    if rules is None or "data" not in rules:
        return None

    ids = list(map(lambda rule: rule["id"], rules["data"]))
    payload = {"delete": {"ids": ids}}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload
    )
    if response.status_code != 200:
        raise Exception(
            "Cannot delete rules (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    print(json.dumps(response.json()))

    
def set_rules(delete):
    # You can adjust the rules if needed
    sample_rules = [
        {"value": "dog has:images", "tag": "dog pictures"},
        {"value": "cat has:images -grumpy", "tag": "cat pictures"},
    ]
    payload = {"add": sample_rules}
    response = requests.post(
        "https://api.twitter.com/2/tweets/search/stream/rules",
        auth=bearer_oauth,
        json=payload,
    )
    if response.status_code != 201:
        raise Exception(
            "Cannot add rules (HTTP {}): {}".format(response.status_code, response.text)
        )
    print(json.dumps(response.json()))

def get_stream(set):
    response = requests.get(
        "https://api.twitter.com/2/tweets/search/stream", auth=bearer_oauth, stream=True,
    )
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Cannot get stream (HTTP {}): {}".format(
                response.status_code, response.text
            )
        )
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))

# %% [markdown]
# ## Test Run

# %%
rules = get_rules()
delete = delete_all_rules(rules)
set = set_rules(delete)
get_stream(set)
# Out:
# {"data": [{"id": "1508968437313413121", "value": "dog has:images", "tag": "dog pictures"}, {"id": "1508968437313413122", "value": "cat has:images -grumpy", "tag": "cat pictures"}], "meta": {"sent": "2022-03-30T13:23:51.322Z", "result_count": 2}}
# {"meta": {"sent": "2022-03-30T13:23:52.753Z", "summary": {"deleted": 2, "not_deleted": 0}}}
# {"data": [{"value": "cat has:images -grumpy", "tag": "cat pictures", "id": "1509159479941681156"}, {"value": "dog has:images", "tag": "dog pictures", "id": "1509159479941681157"}], "meta": {"sent": "2022-03-30T13:23:54.525Z", "summary": {"created": 2, "not_created": 0, "valid": 2, "invalid": 0}}}
# 200
# {
#     "data": {
#         "id": "1509159460350357507",
#         "text": "THAT CAT BUNNN AAAAAA \ud83d\ude0d\ud83d\ude0d\ud83d\ude0d https://t.co/bbCjQf5KVs"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159462761869314",
#         "text": "RT @Punisher_Cat: \u0411\u0443\u043c\u0435\u0440\u0430\u043d\u0433 \u0432\u0435\u0440\u043d\u0443\u043b\u0441\u044f\u2026 https://t.co/bjdRSF9L3B"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159464443981824",
#         "text": "RT @cat_dot_exe: https://t.co/cnf0U3qcSP"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159466016677888",
#         "text": "@CryptobabyGem @AltcoinWorldcom @MiloInu @MiloInu $MILO #MiloInu #MiloInuArmy #BSCGems  #Milo #altcoinseason #MemeSeason \u0130s the best 2022 star inu 1000x https://t.co/jZQVTPHXiF"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681157",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159466721492992",
#         "text": "RT @cat_56chan: \u904a\u3076\u30fc\u30fc\u30fc\u30fc\u30fc\u30fc\uff01\uff01\uff01\uff01\uff01 https://t.co/xRIOYrpzUW"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159468847681541",
#         "text": "RT @valdotpng: be wary of up, dog #ELDENRING https://t.co/c7DmzAsdRJ"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681157",
#             "tag": "dog pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159466914177032",
#         "text": "RT @Punisher_Cat: \u0411\u0443\u043c\u0435\u0440\u0430\u043d\u0433 \u0432\u0435\u0440\u043d\u0443\u043b\u0441\u044f\u2026 https://t.co/bjdRSF9L3B"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159469602820109",
#         "text": "Has anyone see his cat Whiskers?\n\nOh wait\u2026why is he in the news- https://t.co/fYo96paOWf"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159470420869120",
#         "text": "RT @cat_56chan: \u904a\u3076\u30fc\u30fc\u30fc\u30fc\u30fc\u30fc\uff01\uff01\uff01\uff01\uff01 https://t.co/xRIOYrpzUW"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159474669690881",
#         "text": "RT @jenosjae: how to touch a cat (jaemin), a guide by jeno https://t.co/IO4tg8lcb5"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159477165010949",
#         "text": "RT @photo__cat: https://t.co/ASZxvQhCyq"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159477861183491",
#         "text": "RT @TheJay___: How to touch a cat \u0e17\u0e35\u0e48\u0e41\u0e17\u0e49\u0e17\u0e23\u0e39 by Jeno lee https://t.co/H5PuZzG3KX"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159479690264577",
#         "text": "RT @ayaki_black_cat: #\u4eca\u6708\u63cf\u3044\u305f\u7d75\u3092\u6652\u305d\u3046 \n\u4eca\u6708\u306f\u5c11\u306a\u76ee\u306e\u4ee3\u308f\u308a\u306b\u4e00\u679a\u306b\u591a\u4eba\u6570\u63cf\u3044\u305f\uff01\n\u3042\u3068\u306f\u5275\u4f5c\u304c\u4e8c\u679a\u3002 https://t.co/MjPEp5Kmhf"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# {
#     "data": {
#         "id": "1509159480356790272",
#         "text": "RT @okirakuoki: \u3068\u308d\u3051\u308b\u3002\n\n#cat #\u306d\u3053 #\u732b https://t.co/LQy1tdVm1T"
#     },
#     "matching_rules": [
#         {
#             "id": "1509159479941681156",
#             "tag": "cat pictures"
#         }
#     ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-3b567908fb05> in <module>()
#       2 delete = delete_all_rules(rules)
#       3 set = set_rules(delete)
# ----> 4 get_stream(set)
#
# <ipython-input-13-b2304df3543b> in get_stream(set)
#      59             )
#      60         )
# ---> 61     for response_line in response.iter_lines():
#      62         if response_line:
#      63             json_response = json.loads(response_line)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     802         pending = None
#     803
# --> 804         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     805
#     806             if pending is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/requests/models.py in generate()
#     758             if hasattr(self.raw, 'stream'):
#     759                 try:
# --> 760                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     761                         yield chunk
#     762                 except ProtocolError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     430         """
#     431         if self.chunked and self.supports_chunked_reads():
# --> 432             for line in self.read_chunked(amt, decode_content=decode_content):
#     433                 yield line
#     434         else:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     596         with self._error_catcher():
#     597             while True:
# --> 598                 self._update_chunk_length()
#     599                 if self.chunk_left == 0:
#     600                     break
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     538         if self.chunk_left is not None:
#     539             return
# --> 540         line = self._fp.fp.readline()
#     541         line = line.split(b';', 1)[0]
#     542         try:
#
# ~/anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~/anaconda3/lib/python3.6/ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:
